# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
incomes = np.random.normal(10000, 7500, 10000)

# %%
incomes = np.append(incomes, [ 10000000])

# %%
incomes
# Out:
# array([1.28776631e+04, 1.11109944e+04, 5.44360584e+03, ...,
#        6.22204657e+03, 6.70629060e+03, 1.00000000e+07])

# %%
incomes.mean()
# Out:
# 10916.878239011383

# %%
plt.hist(incomes, 50)
plt.show()

# %%
def remove_outliers(data):
    median = np.median(data)
    std = np.std(data)
    filter_values =[]
    for e in data:
        if median - 2*std < e < median + 2*std:
            filter_values.append(e)
    return np.array(filter_values)

# %%
filtered = remove_outliers(incomes)
plt.hist(filtered, 50)
plt.show()

# %%
incomes.mean()
# Out:
# 10916.878239011383

# %%
incomes.std()
# Out:
# 100166.75501085207

# %%
#try to find the median here.

# %%
random_ages = np.random.randint(18, high=91, size=500)

# %%
#learning scipy here.


from scipy import stats

# %%
mode = stats.mode(random_ages)
print(mode)
# Out:
# ModeResult(mode=26, count=11)

# %%
#Redefining the incomes so that variance can be found using the formula.

# %%
incomes = np.random.normal(100, 5, 10000)

# %%
plt.hist(incomes, 100)
# Out:
# (array([  1.,   0.,   0.,   0.,   2.,   2.,   1.,   4.,   4.,   5.,   5.,
#           1.,   7.,   6.,  12.,  10.,   8.,  10.,  12.,  20.,  24.,  24.,
#          31.,  35.,  44.,  56.,  50.,  63.,  83.,  95., 110.,  92., 116.,
#         123., 128., 134., 180., 169., 176., 192., 192., 222., 231., 252.,
#         246., 299., 297., 288., 297., 268., 297., 292., 292., 286., 293.,
#         272., 277., 280., 275., 272., 229., 236., 191., 196., 167., 161.,
#         145., 130., 133., 133., 118.,  87.,  90.,  73.,  72.,  56.,  46.,
#          49.,  37.,  32.,  31.,  24.,  21.,  12.,  12.,  12.,   9.,   6.,
#           4.,   5.,   1.,   3.,   4.,   4.,   1.,   1.,   1.,   1.,   3.,
#           1.]),
#  array([ 81.19540223,  81.56215319,  81.92890415,  82.29565511,
#          82.66240607,  83.02915703,  83.39590799,  83.76265894,
#          84.1294099 ,  84.49616086,  84.86291182,  85.22966278,
#          85.59641374,  85.9631647 ,  86.32991566,  86.69666662,
#          87.06341757,  87.43016853,  87.79691949,  88.16367045,
#          88.53042141,  88.89717237,  89.26392333,  89.63067429,
#          89.99742525,  90.3641762 ,  90.73092716,  91.09767812,
#          91.46442908,  91.83118004,  92.197931  ,  92.56468196,
#          92.93143292,  93.29818387,  93.66493483,  94.03168579,
#          94.39843675,  94.76518771,  95.13193867,  95.49868963,
#          95.86544059,  96.23219155,  96.5989425 ,  96.96569346,
#          97.33244442,  97.69919538,  98.06594634,  98.4326973 ,
#          98.79944826,  99.16619922,  99.53295018,  99.89970113,
#         100.26645209, 100.63320305, 100.99995401, 101.36670497,
#         101.73345593, 102.10020689, 102.46695785, 102.83370881,
#         103.20045976, 103.56721072, 103.93396168, 104.30071264,
#         104.6674636 , 105.03421456, 105.40096552, 105.76771648,
#         106.13446743, 106.50121839, 106.86796935, 107.23472031,
#         107.60147127, 107.96822223, 108.33497319, 108.70172415,
#         109.06847511, 109.43522606, 109.80197702, 110.16872798,
#         110.53547894, 110.9022299 , 111.26898086, 111.63573182,
#         112.00248278, 112.36923374, 112.73598469, 113.10273565,
#         113.46948661, 113.83623757, 114.20298853, 114.56973949,
#         114.93649045, 115.30324141, 115.66999237, 116.03674332,
#         116.40349428, 116.77024524, 117.1369962 , 117.50374716,
#         117.87049812]),
#  <BarContainer object of 100 artists>)

# %%
print("standard deviation = ", np.std(incomes))
print("variance = ", np.var(incomes))

#it is true, the variance is just the square of std. so the values are matching perfectly ig
# Out:
# standard deviation =  4.96534271406724
# variance =  24.654628268140623
